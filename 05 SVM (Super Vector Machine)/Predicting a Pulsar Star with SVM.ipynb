# %%
import numpy as np
import pandas as pd

# %%
stars = pd.read_csv('pulsar_stars.csv')
stars.head()
# Out:
#     Mean of the integrated profile  \
# 0                       140.562500
# 1                       102.507812
# 2                       103.015625
# 3                       136.750000
# 4                        88.726562
#
#     Standard deviation of the integrated profile  \
# 0                                      55.683782
# 1                                      58.882430
# 2                                      39.341649
# 3                                      57.178449
# 4                                      40.672225
#
#     Excess kurtosis of the integrated profile  \
# 0                                   -0.234571
# 1                                    0.465318
# 2                                    0.323328
# 3                                   -0.068415
# 4                                    0.600866
#
#     Skewness of the integrated profile   Mean of the DM-SNR curve  \
# 0                            -0.699648                   3.199833
# 1                            -0.515088                   1.677258
# 2                             1.051164                   3.121237
# 3                            -0.636238                   3.642977
# 4                             1.123492                   1.178930
#
#     Standard deviation of the DM-SNR curve  \
# 0                                19.110426
# 1                                14.860146
# 2                                21.744669
# 3                                20.959280
# 4                                11.468720
#
#     Excess kurtosis of the DM-SNR curve   Skewness of the DM-SNR curve  \
# 0                              7.975532                      74.242225
# 1                             10.576487                     127.393580
# 2                              7.735822                      63.171909
# 3                              6.896499                      53.593661
# 4                             14.269573                     252.567306
#
#    target_class
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
stars.describe()
X = stars.iloc[:, :8]
X.head()
# Out:
#     Mean of the integrated profile  \
# 0                       140.562500
# 1                       102.507812
# 2                       103.015625
# 3                       136.750000
# 4                        88.726562
#
#     Standard deviation of the integrated profile  \
# 0                                      55.683782
# 1                                      58.882430
# 2                                      39.341649
# 3                                      57.178449
# 4                                      40.672225
#
#     Excess kurtosis of the integrated profile  \
# 0                                   -0.234571
# 1                                    0.465318
# 2                                    0.323328
# 3                                   -0.068415
# 4                                    0.600866
#
#     Skewness of the integrated profile   Mean of the DM-SNR curve  \
# 0                            -0.699648                   3.199833
# 1                            -0.515088                   1.677258
# 2                             1.051164                   3.121237
# 3                            -0.636238                   3.642977
# 4                             1.123492                   1.178930
#
#     Standard deviation of the DM-SNR curve  \
# 0                                19.110426
# 1                                14.860146
# 2                                21.744669
# 3                                20.959280
# 4                                11.468720
#
#     Excess kurtosis of the DM-SNR curve   Skewness of the DM-SNR curve
# 0                              7.975532                      74.242225
# 1                             10.576487                     127.393580
# 2                              7.735822                      63.171909
# 3                              6.896499                      53.593661
# 4                             14.269573                     252.567306

# %%
stars.shape
# Out:
# (17898, 9)

# %%
y = stars.target_class
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: target_class, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
print(X_train)
scaler.fit(X_train)
# Out:
#         Mean of the integrated profile  \
# 7056                         81.203125
# 11766                       135.500000
# 391                         135.414062
# 6981                         99.875000
# 9570                        143.015625
# ...                                ...
# 7648                         10.578125
# 4893                        143.921875
# 16385                       121.109375
# 16487                        97.414062
# 4902                        115.164062
#
#         Standard deviation of the integrated profile  \
# 7056                                       38.252116
# 11766                                      51.450674
# 391                                        44.587612
# 6981                                       40.146996
# 9570                                       54.771540
# ...                                              ...
# 7648                                       35.128027
# 4893                                       51.065156
# 16385                                      44.677181
# 16487                                      53.132136
# 4902                                       61.876613
#
#         Excess kurtosis of the integrated profile  \
# 7056                                     0.735803
# 11766                                   -0.100779
# 391                                      0.022410
# 6981                                     0.503975
# 9570                                    -0.413088
# ...                                           ...
# 7648                                     5.575468
# 4893                                    -0.021782
# 16385                                    0.273867
# 16487                                    0.361491
# 4902                                     0.155001
#
#         Skewness of the integrated profile   Mean of the DM-SNR curve  \
# 7056                              2.430891                   3.629599
# 11766                            -0.291634                   0.950669
# 391                               0.686494                   3.001672
# 6981                              0.995147                   2.515050
# 9570                             -0.288131                   1.898829
# ...                                    ...                        ...
# 7648                             31.867382                  94.964883
# 4893                             -0.110498                   8.905518
# 16385                             0.609150                   2.512542
# 16487                            -0.059130                   1.042642
# 4902                             -0.821791                 122.153846
#
#         Standard deviation of the DM-SNR curve  \
# 7056                                 22.363688
# 11766                                11.027106
# 391                                  19.192215
# 6981                                 15.487041
# 9570                                 18.261405
# ...                                        ...
# 7648                                 52.072327
# 4893                                 38.271870
# 16385                                14.863223
# 16487                                13.620294
# 4902                                104.020120
#
#         Excess kurtosis of the DM-SNR curve   Skewness of the DM-SNR curve
# 7056                               7.125256                      54.756813
# 11766                             16.161517                     308.997681
# 391                                8.135408                      75.936816
# 6981                               8.514690                      92.114768
# 9570                              11.132796                     131.395727
# ...                                     ...                            ...
# 7648                               0.977852                       0.824462
# 4893                               4.535310                      20.030672
# 16385                              8.798182                     102.400763
# 16487                             14.183005                     211.710872
# 4902                              -0.249914                      -1.826927
#
# [14318 rows x 8 columns]
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
X_train = scaler.transform(X_train)
X_test
